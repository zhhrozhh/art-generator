# %%
from AGen import *
# Out:
# Using TensorFlow backend.

# %%
import matplotlib.pyplot as plt
# %matplotlib notebook

# %%
VGG19Gen('/home/hanghang/Desktop/download.jpg','/home/hanghang/Downloads/webwxgetmsgimg (1).jpg',size = (720//2,540//2))
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
# array([[[ 0.00872051,  0.13812377,  0.11312873],
#         [ 0.2633048 ,  0.09305474,  0.16829753],
#         [ 0.143229  ,  0.02754224,  0.10626313],
#         ...,
#         [ 0.28758999,  0.55728816,  0.37278352],
#         [ 0.47992917,  0.68560538,  0.10612005],
#         [-0.0557397 ,  0.79505226, -0.01716694]],
#
#        [[-0.03995985,  0.0159394 ,  0.13634906],
#         [ 0.24576083,  0.02469462,  0.28571484],
#         [-0.02031288,  0.04353863,  0.34409364],
#         ...,
#         [ 0.58564598,  0.45545533,  0.66752627],
#         [ 1.11768947,  0.69956601,  0.42433833],
#         [ 0.44397958,  0.86839247,  0.48007265]],
#
#        [[ 0.00231067, -0.00478699,  0.37883047],
#         [ 0.26868549,  0.08634746,  0.44784624],
#         [-0.06722038, -0.07573958,  0.31740892],
#         ...,
#         [ 0.49506417, -0.01193017,  0.6857099 ],
#         [ 0.83301379,  0.51650791,  0.42391119],
# ...
