# %%
from AGen import *
import matplotlib.pyplot as plt
# %matplotlib notebook
VGG19Gen(
    '/home/hanghang/Desktop/download.jpg',
    '/home/hanghang/Downloads/webwxgetmsgimg (3).jpg',
    size = (540//2,720//2),
    denoise = 'gaussian'
)
# Out:
# Using TensorFlow backend.
# <img src="data:image/png;base64,..." width="639.9999861283738">
# array([[[ 0.34585604,  0.53255823,  0.51166471],
#         [ 0.23240105,  0.4566282 ,  0.31500597],
#         [-0.07430477,  0.24365671,  0.1621963 ],
#         ...,
#         [ 0.16801476,  0.44189135,  0.35301121],
#         [ 0.23421606,  0.67206422,  0.24994336],
#         [ 0.11700115,  0.6826415 ,  0.22224444]],
#
#        [[ 0.1011743 ,  0.37894456,  0.26978221],
#         [-0.03964508,  0.08296448,  0.0490404 ],
#         [ 0.25654805,  0.09467511,  0.32544485],
#         ...,
#         [ 0.3912181 ,  0.32300154,  0.49304888],
#         [ 0.76529635,  0.63979647,  0.58153982],
#         [ 0.17913724,  0.53324589,  0.30697662]],
#
#        [[ 0.08909489,  0.17585524,  0.15619874],
#         [ 0.03353791,  0.08270217,  0.16880192],
#         [ 0.18571935,  0.0075988 ,  0.28138767],
#         ...,
#         [ 0.56358258, -0.02593316,  0.62232005],
#         [ 0.69280174,  0.32266725,  0.5017361 ],
#         [ 0.12225263,  0.45939521,  0.37767663]],
#
#        ...,
#        [[ 0.06592667,  0.13472496,  0.14195326],
#         [ 0.17864036,  0.13506548,  0.13359693],
#         [ 0.34555066, -0.08988662, -0.03750914],
#         ...,
#         [ 0.49717806,  0.08471945,  0.34807899],
#         [ 0.53028109,  0.45384891,  0.26995304],
#         [ 0.21854292,  0.74324344,  0.24495229]],
#
#        [[-0.07235576,  0.09705723,  0.10671496],
#         [ 0.03129485,  0.08642931,  0.0196737 ],
#         [ 0.18248687,  0.11008199,  0.01669796],
#         ...,
#         [ 0.14773112, -0.10548836,  0.06304555],
#         [ 0.23063928,  0.11723279,  0.0553127 ],
#         [ 0.21131255,  0.48985816,  0.19003559]],
#
#        [[-0.15149382,  0.25366252,  0.12838849],
#         [-0.27824259,  0.47142203,  0.22506247],
#         [ 0.06934178,  0.26219338,  0.07353315],
#         ...,
#         [-0.31248878,  0.25810884,  0.12663699],
#         [-0.16846923,  0.47432975,  0.19290227],
#         [-0.04659939,  0.37945582,  0.04058625]]])

# %%
q[q>1] = 1
q[q<0] = 0

# %%
plt.imsave("/home/hanghang/Desktop/asdasdas.png",q)

# %%
c = plt.imread('/home/hanghang/Desktop/download.jpg')

# %%
c.std()
# Out:
# 47.960087018658491

# %%
s = estimate_sigma(q,N = 4)

# %%
from dipy.denoise.nlmeans import nlmeans
from dipy.denoise.noise_estimate import estimate_sigma

# %%
w = np.ones((1,3,4,3))

# %%
w.reshape(w.shape[1:]).shape
# Out:
# (3, 4, 3)

# %%
np.ones(c.shape).shape
# Out:
# (200, 252, 3)

# %%
def test_nlmeans_random_noise():
    S0 = 100 + 2 * np.random.standard_normal((22, 23, 30))
 
    S0n = nlmeans(S0, sigma=np.ones((22, 23, 30)) * np.std(S0), rician=False)
 
    print(S0.mean(), S0.min(), S0.max())
    print(S0n.mean(), S0n.min(), S0n.max())

# %%
    S0 = 100 + 2 * np.random.standard_normal((3, 33, 33))
 
    S0n = nlmeans(S0, sigma=np.ones((3, 33, 33)) * np.std(S0), rician=False)
 
    print(S0.mean(), S0.min(), S0.max())
    print(S0n.mean(), S0n.min(), S0n.max())
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-55-3e75770cab56> in <module>()
#       1 S0 = 100 + 2 * np.random.standard_normal((3, 33, 33))
#       2
# ----> 3 S0n = nlmeans(S0, sigma=np.ones((3, 33, 33)) * np.std(S0), rician=False)
#       4
#       5 print(S0.mean(), S0.min(), S0.max())
#
# /home/hanghang/anaconda3/lib/python3.6/site-packages/dipy/denoise/nlmeans.py in nlmeans(arr, sigma, mask, patch_radius, block_radius, rician, num_threads)
#      56         return nlmeans_3d(arr, mask, sigma,
#      57                           patch_radius, block_radius,
# ---> 58                           rician, num_threads).astype(arr.dtype)
#      59
#      60     elif arr.ndim == 4:
#
# dipy/denoise/denspeed.pyx in dipy.denoise.denspeed.nlmeans_3d (dipy/denoise/denspeed.c:2688)()
#
# dipy/denoise/denspeed.pyx in dipy.denoise.denspeed.add_padding_reflection (dipy/denoise/denspeed.c:4825)()
#
# IndexError: Out of bounds on buffer access (axis 0)

# %%
plt.figure()
q = plt.subplot(151)
g = plt.imread('/home/hanghang/Desktop/download.jpg')
q.imshow(g)
# Out:
# <img src="data:image/png;base64,..." width="348.1818106351807">

# %%
(np.ones((22, 23, 30)) * np.std(S0)).shape
# Out:
# (22, 23, 30)
